# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame(np.random.randint(1,100,(5,5)), index= 'A B C D E'.split(), columns='V W X Y Z'.split())
data
# Out:
#     V   W   X   Y   Z
# A  98  46  54   6  55
# B  22  57  27  96  91
# C  11  92  85  75  58
# D  58  83  91  70  18
# E  15  54  92  87  84

# %% [markdown]
# # Insert Data

# %%
data.loc['Baru'] = np.random.rand(5)

# %%
data
# Out:
#               V          W          X         Y          Z
# A     98.000000  46.000000  54.000000   6.00000  55.000000
# B     22.000000  57.000000  27.000000  96.00000  91.000000
# C     11.000000  92.000000  85.000000  75.00000  58.000000
# D     58.000000  83.000000  91.000000  70.00000  18.000000
# E     15.000000  54.000000  92.000000  87.00000  84.000000
# Baru   0.506491   0.138411   0.735289   0.76781   0.720852

# %%
data['Kolom'] = np.random.randn(6)
data
# Out:
#               V          W          X         Y          Z     Kolom
# A     98.000000  46.000000  54.000000   6.00000  55.000000  0.448402
# B     22.000000  57.000000  27.000000  96.00000  91.000000  0.909938
# C     11.000000  92.000000  85.000000  75.00000  58.000000  0.075466
# D     58.000000  83.000000  91.000000  70.00000  18.000000 -0.928437
# E     15.000000  54.000000  92.000000  87.00000  84.000000 -1.388211
# Baru   0.506491   0.138411   0.735289   0.76781   0.720852  0.690397

# %%
data = pd.concat([data, data.loc[['Baru', 'Fix']]])
# Out:
#               V          W          X          Y          Z     Kolom  \
# A     80.000000  38.000000  53.000000  20.000000  23.000000 -0.027166
# B      6.000000  59.000000  66.000000  44.000000  50.000000  0.720451
# C     18.000000  74.000000  99.000000  24.000000  87.000000  0.849573
# D     87.000000  33.000000  89.000000  30.000000  88.000000  0.881330
# E     46.000000  41.000000  49.000000  47.000000  36.000000  0.775187
# Baru   9.000000   7.000000   4.000000   6.000000   9.000000  3.000000
# Fix    0.422213   0.171626   0.676757   0.498013   0.145963  0.249332
# Baru   9.000000   7.000000   4.000000   6.000000   9.000000  3.000000
# Fix    0.422213   0.171626   0.676757   0.498013   0.145963  0.249332
#
#            Baru
# A     11.000000
# B      6.000000
# C     13.000000
# D      6.000000
# E     14.000000
# Baru   8.000000
# Fix    0.538218
# Baru   8.000000
# Fix    0.538218

# %%
data
# Out:
#               V          W          X          Y          Z     Kolom  \
# A     80.000000  38.000000  53.000000  20.000000  23.000000 -0.027166
# B      6.000000  59.000000  66.000000  44.000000  50.000000  0.720451
# C     18.000000  74.000000  99.000000  24.000000  87.000000  0.849573
# D     87.000000  33.000000  89.000000  30.000000  88.000000  0.881330
# E     46.000000  41.000000  49.000000  47.000000  36.000000  0.775187
# Baru   9.000000   7.000000   4.000000   6.000000   9.000000  3.000000
# Fix    0.422213   0.171626   0.676757   0.498013   0.145963  0.249332
#
#            Baru
# A     11.000000
# B      6.000000
# C     13.000000
# D      6.000000
# E     14.000000
# Baru   8.000000
# Fix    0.538218

# %%
data
# Out:
#     V   W   X   Y   Z
# A  29  15  33  96  27
# B  78  88  55  53   4
# C  20  47  26  50  38
# D  59  23  95  94  19
# E  22  17  38  49  14

# %%
data.loc[5] = np.random.rand(5)
data
# Out:
#            V          W          X          Y          Z
# A  29.000000  15.000000  33.000000  96.000000  27.000000
# B  78.000000  88.000000  55.000000  53.000000   4.000000
# C  20.000000  47.000000  26.000000  50.000000  38.000000
# D  59.000000  23.000000  95.000000  94.000000  19.000000
# E  22.000000  17.000000  38.000000  49.000000  14.000000
# 5   0.898775   0.836028   0.715517   0.875791   0.845966

# %%
data = pd.DataFrame(np.random.randint(1,100,(5,5)), columns='V W X Y Z'.split())
data
type(data.iloc[3,3])
# Out:
# numpy.int32

# %%
data.loc[5] = np.random.randn(5)
type(data.iloc[3,3])
# Out:
# numpy.float64

# %%
data.insert(3, 'New', np.random.rand(5))

# %%
data
# Out:
#     V   W   X       New   Y   Z
# 0  23  86  18  0.044464  41  87
# 1  27  68  26  0.542964  69   7
# 2  90  37  68  0.477208  48  70
# 3  32  50  75  0.027032   2  49
# 4  62  25  60  0.701007  97  96

# %% [markdown]
# # Delete Data

# %%
data
# Out:
#     V       New       New   W   X       New   Y   Z
# 0  23  0.278437  0.858883  86  18  0.044464  41  87
# 1  27  0.028540  0.448433  68  26  0.542964  69   7
# 2  90  0.852487  0.022401  37  68  0.477208  48  70
# 3  32  0.279616  0.406166  50  75  0.027032   2  49
# 4  62  0.519719  0.035683  25  60  0.701007  97  96

# %%
data = pd.DataFrame(np.random.randint(1,100,(5,5)), index= 'A B C D E'.split(), columns='V W X Y Z'.split())
data
# Out:
#     V   W   X   Y   Z
# A  75  81  76  21  54
# B  39  96  38  46  32
# C  16  88  47  23  57
# D  64  37   7  79   9
# E  74  59  44  47  48

# %%
data.drop('Z', axis=1)
# Out:
#     V   W   X   Y
# A  75  81  76  21
# B  39  96  38  46
# C  16  88  47  23
# D  64  37   7  79
# E  74  59  44  47

# %%
data
# Out:
#     V   W   X   Y   Z
# A  75  81  76  21  54
# B  39  96  38  46  32
# C  16  88  47  23  57
# D  64  37   7  79   9
# E  74  59  44  47  48

# %%
data.drop('V', axis=1, inplace=True)

# %%
data
# Out:
#     W   X   Y
# A  81  76  21
# B  96  38  46
# C  88  47  23
# D  37   7  79
# E  59  44  47

# %%
data.drop(['D','B'], axis=0, inplace=True)

# %%
data
# Out:
#     W   X   Y
# A  81  76  21
# C  88  47  23

# %% [markdown]
# # More About Index

# %%
data = pd.DataFrame(np.random.randint(1,100,(5,5)), index= 'A B C D E'.split(), columns='V W X Y Z'.split())
data
# Out:
#     V   W   X   Y   Z
# A  72  53  97  77  12
# B  94  28  74  18  21
# C  64  74  78   4  83
# D  24  45  64  20  48
# E  33  32  77  69  63

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#   index   V   W   X   Y   Z
# 0     A  72  53  97  77  12
# 1     B  94  28  74  18  21
# 2     C  64  74  78   4  83
# 3     D  24  45  64  20  48
# 4     E  33  32  77  69  63

# %%
data.drop('index', axis=1, inplace=True)
data
# Out:
#     V   W   X   Y   Z
# 0  72  53  97  77  12
# 1  94  28  74  18  21
# 2  64  74  78   4  83
# 3  24  45  64  20  48
# 4  33  32  77  69  63

# %%
data['IndexBaru'] = 'Jawa Kalimantan Sulawesi Papua Sumatra'.split()

# %%
data
# Out:
#     V   W   X   Y   Z   IndexBaru
# 0  72  53  97  77  12        Jawa
# 1  94  28  74  18  21  Kalimantan
# 2  64  74  78   4  83    Sulawesi
# 3  24  45  64  20  48       Papua
# 4  33  32  77  69  63     Sumatra

# %%
data.set_index('IndexBaru', inplace=True)

# %%
data
# Out:
#              V   W   X   Y   Z
# IndexBaru
# Jawa        72  53  97  77  12
# Kalimantan  94  28  74  18  21
# Sulawesi    64  74  78   4  83
# Papua       24  45  64  20  48
# Sumatra     33  32  77  69  63

# %%
data[['V', 'Z']]
# Out:
#              V   Z
# IndexBaru
# Jawa        72  12
# Kalimantan  94  21
# Sulawesi    64  83
# Papua       24  48
# Sumatra     33  63

# %%
data.loc['Jawa']
# Out:
# V    72
# W    53
# X    97
# Y    77
# Z    12
# Name: Jawa, dtype: int32

# %% [markdown]
# # Multi Index

# %%
Luar = ['Bandung', 'Bandung', 'Bandung', 'Bandung', 'Bandung', 'Bandung',
'Kendari', 'Kendari', 'Kendari', 'Kendari', 'Kendari', 'Kendari',
'Solo', 'Solo', 'Solo', 'Solo', 'Solo', 'Solo']
Dalam = [1,2,3,4,5,6,1,2,3,4,5,6,1,2,3,4,5,6]
index = list(zip(Luar,Dalam))
index
# Out:
# [('Bandung', 1),
#  ('Bandung', 2),
#  ('Bandung', 3),
#  ('Bandung', 4),
#  ('Bandung', 5),
#  ('Bandung', 6),
#  ('Kendari', 1),
#  ('Kendari', 2),
#  ('Kendari', 3),
#  ('Kendari', 4),
#  ('Kendari', 5),
#  ('Kendari', 6),
#  ('Solo', 1),
#  ('Solo', 2),
#  ('Solo', 3),
#  ('Solo', 4),
#  ('Solo', 5),
#  ('Solo', 6)]

# %%
index = pd.MultiIndex.from_tuples(index)
index
# Out:
# MultiIndex([('Bandung', 1),
#             ('Bandung', 2),
#             ('Bandung', 3),
#             ('Bandung', 4),
#             ('Bandung', 5),
#             ('Bandung', 6),
#             ('Kendari', 1),
#             ('Kendari', 2),
#             ('Kendari', 3),
#             ('Kendari', 4),
#             ('Kendari', 5),
#             ('Kendari', 6),
#             (   'Solo', 1),
#             (   'Solo', 2),
#             (   'Solo', 3),
#             (   'Solo', 4),
#             (   'Solo', 5),
#             (   'Solo', 6)],
#            )

# %%
df = pd.DataFrame(np.random.randint(1,10,(18,5)), index = index, columns=('Cabang A', 'Cabang B', 'Cabang C', 'Cabang D', 'Cabang E'))

# %%
df
# Out:
#            Cabang A  Cabang B  Cabang C  Cabang D  Cabang E
# Bandung 1         3         4         8         1         1
#         2         3         3         1         4         4
#         3         6         8         4         6         3
#         4         4         2         3         5         5
#         5         4         6         6         5         9
#         6         8         9         3         1         4
# Kendari 1         6         3         4         7         6
#         2         2         1         7         5         9
#         3         8         5         4         2         9
#         4         6         1         7         3         3
#         5         1         5         2         6         2
#         6         8         7         6         9         3
# Solo    1         2         5         7         7         5
#         2         1         7         4         3         6
#         3         2         2         9         4         3
# ...

# %%
df['Cabang A']
# Out:
# Bandung  1    3
#          2    3
#          3    6
#          4    4
#          5    4
#          6    8
# Kendari  1    6
#          2    2
#          3    8
#          4    6
#          5    1
#          6    8
# Solo     1    2
#          2    1
#          3    2
#          4    6
#          5    6
#          6    5
# Name: Cabang A, dtype: int32

# %%
df.loc['Kendari']
# Out:
#    Cabang A  Cabang B  Cabang C  Cabang D  Cabang E
# 1         6         3         4         7         6
# 2         2         1         7         5         9
# 3         8         5         4         2         9
# 4         6         1         7         3         3
# 5         1         5         2         6         2
# 6         8         7         6         9         3

# %%
df.xs('Bandung')
# Out:
#    Cabang A  Cabang B  Cabang C  Cabang D  Cabang E
# 1         3         4         8         1         1
# 2         3         3         1         4         4
# 3         6         8         4         6         3
# 4         4         2         3         5         5
# 5         4         6         6         5         9
# 6         8         9         3         1         4

# %%
df.loc['Solo'].loc[[4,6]]
# Out:
#    Cabang A  Cabang B  Cabang C  Cabang D  Cabang E
# 4         6         8         1         5         3
# 6         5         4         4         4         3

# %%
df.xs(['Bandung', 3])
# Out:
# Cabang A    6
# Cabang B    8
# Cabang C    4
# Cabang D    6
# Cabang E    3
# Name: (Bandung, 3), dtype: int32

# %%
df
# Out:
#            Cabang A  Cabang B  Cabang C  Cabang D  Cabang E
# Bandung 1         3         4         8         1         1
#         2         3         3         1         4         4
#         3         6         8         4         6         3
#         4         4         2         3         5         5
#         5         4         6         6         5         9
#         6         8         9         3         1         4
# Kendari 1         6         3         4         7         6
#         2         2         1         7         5         9
#         3         8         5         4         2         9
#         4         6         1         7         3         3
#         5         1         5         2         6         2
#         6         8         7         6         9         3
# Solo    1         2         5         7         7         5
#         2         1         7         4         3         6
#         3         2         2         9         4         3
# ...

# %%
df.index.names = ['Kota', 'Lokasi']

# %%
df
# Out:
#                 Cabang A  Cabang B  Cabang C  Cabang D  Cabang E
# Kota    Lokasi
# Bandung 1              3         4         8         1         1
#         2              3         3         1         4         4
#         3              6         8         4         6         3
#         4              4         2         3         5         5
#         5              4         6         6         5         9
#         6              8         9         3         1         4
# Kendari 1              6         3         4         7         6
#         2              2         1         7         5         9
#         3              8         5         4         2         9
#         4              6         1         7         3         3
#         5              1         5         2         6         2
#         6              8         7         6         9         3
# Solo    1              2         5         7         7         5
# ...

# %% [markdown]
# # Latihan 1
# - Insert Data
# - Delete Data
# - More About Index
# - Multi Index
#
# 1. Buat sebuah data frame yang terdi dari 5 baris 6 kolom. Namanya kolom dan indexnya bebas. Isi dari setiap kolomnya coba dibedakan.
# 2. Dari dataframe yang dibuat, masukan sebuah kolom pada index ke 3 dan 0 yang nilainya adalah perkalian kolom index 0 awal dengan 10 (untuk kolom baru index 3), dan nilai mod dari index kolom 4 dan 5 pada kolom awal 9untuk kolom baru index 0)
# 3. Tampilkan dataframe baru tersebut
# 4. Coba tampilkan seluruh dataframe yang memiliki nilai > 5. Simpanlah kedalam sebuah dataframe baru
# 5. Dari dataframe baru pada nomor sebelumnya, hapuslah 2 kolom yang jumlah NA nya paling banyak. Drop kolomnya secara permanen
# 6. Dari dataframe tersebut, resetlah index nya kemudian buatlah sebuah index baru
# 7. Buatlah sebuah dataframe dengan multi index

# %% [markdown]
# # Pandas Function

# %%
import seaborn as sns

# %%
data = sns.load_dataset("titanic")
print (type(data))
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
data[['survived','pclass', 'sex']].head(20)
# Out:
#     survived  pclass     sex
# 0          0       3    male
# 1          1       1  female
# 2          1       3  female
# 3          1       1  female
# 4          0       3    male
# 5          0       3    male
# 6          0       1    male
# 7          0       3    male
# 8          1       3  female
# 9          1       2  female
# 10         1       3  female
# 11         1       1  female
# 12         0       3    male
# 13         0       3    male
# 14         0       3  female
# 15         1       2  female
# 16         0       3    male
# 17         1       2    male
# 18         0       3  female
# 19         1       3  female

# %%
data.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
data.iloc[:,[3,5,7]].tail(2)
# Out:
#       age  parch embarked
# 889  26.0      0        C
# 890  32.0      0        Q

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.shape
# Out:
# (891, 15)

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.describe(exclude= 'number')
# Out:
#          sex embarked  class  who adult_male deck  embark_town alive alone
# count    891      889    891  891        891  203          889   891   891
# unique     2        3      3    3          2    7            3     2     2
# top     male        S  Third  man       True    C  Southampton    no  True
# freq     577      644    491  537        537   59          644   549   537

# %%
data.describe(exclude= 'object')
# Out:
#           survived      pclass         age       sibsp       parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      0.383838    2.308642   29.699118    0.523008    0.381594
# std       0.486592    0.836071   14.526497    1.102743    0.806057
# min       0.000000    1.000000    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   38.000000    1.000000    0.000000
# max       1.000000    3.000000   80.000000    8.000000    6.000000
#
#               fare  class adult_male deck alone
# count   891.000000    891        891  203   891
# unique         NaN      3          2    7     2
# ...

# %%
data.mean()
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
data.std()
# Out:
# survived       0.486592
# pclass         0.836071
# age           14.526497
# sibsp          1.102743
# parch          0.806057
# fare          49.693429
# adult_male     0.489615
# alone          0.489615
# dtype: float64

# %%
data.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
data['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['deck'].unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['C', 'E', 'G', 'D', 'A', 'B', 'F']

# %%
data['sex'].nunique()
# Out:
# 2

# %%
data['sex'].value_counts()/len(data)*100
# Out:
# male      64.758698
# female    35.241302
# Name: sex, dtype: float64

# %% [markdown]
# # Missing Value

# %%
misvaldf = pd.DataFrame({'A' : [1,2,np.nan],
'B' : [10,np.nan,np.nan],
'C' : [1,3,5]})

# %%
misvaldf
# Out:
#      A     B  C
# 0  1.0   NaN  1
# 1  2.0   NaN  3
# 2  NaN  10.0  5

# %%
misvaldf.isna()
# Out:
#        A      B      C
# 0  False   True  False
# 1  False   True  False
# 2   True  False  False

# %%
misvaldf.isna().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
misvaldf.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
misvaldf
# Out:
#      A     B  C
# 0  1.0   NaN  1
# 1  2.0   NaN  3
# 2  NaN  10.0  5

# %%
misvaldf.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  3
# 2  5

# %%
misvaldf.dropna(thresh=2, axis = 1)
# Out:
#      A  C
# 0  1.0  1
# 1  2.0  3
# 2  NaN  5

# %%
misvaldf
# Out:
#      A     B  C
# 0  1.0  10.0  1
# 1  2.0   NaN  3
# 2  NaN   NaN  5

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
datadrop = data.drop('deck', axis=1)
datadrop
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
datadrop.dropna(inplace=True)
datadrop
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
misvaldf
# Out:
#      A     B  C
# 0  1.0  10.0  1
# 1  2.0   NaN  3
# 2  NaN   NaN  5

# %%
misvaldf['A'].fillna(value=misvaldf['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# # Aggregating

# %%
JK = data.groupby('sex')

# %%
JK.mean()
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
JK.describe().transpose()
# Out:
# sex                 female        male
# survived count  314.000000  577.000000
#          mean     0.742038    0.188908
#          std      0.438211    0.391775
#          min      0.000000    0.000000
#          25%      0.000000    0.000000
#          50%      1.000000    0.000000
#          75%      1.000000    0.000000
#          max      1.000000    1.000000
# pclass   count  314.000000  577.000000
#          mean     2.159236    2.389948
#          std      0.857290    0.813580
#          min      1.000000    1.000000
#          25%      1.000000    2.000000
#          50%      2.000000    3.000000
#          75%      3.000000    3.000000
#          max      3.000000    3.000000
# age      count  261.000000  453.000000
#          mean    27.915709   30.726645
#          std     14.110146   14.678201
#          min      0.750000    0.420000
#          25%     18.000000   21.000000
#          50%     27.000000   29.000000
#          75%     37.000000   39.000000
# ...
